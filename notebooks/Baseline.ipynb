# %%
from sklearn.model_selection import KFold
from sklearn.metrics import root_mean_squared_error
import lightgbm as lgb

# %% [markdown]
# ### Features
# * Derivatives and double derivatives
# * Direction
# * We may first make a model predict derivates and then use it
#
# * Boring is a continous mission
#     * Must use predictions few seconds ago as well.
#     *
